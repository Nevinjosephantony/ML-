# %% [markdown]
# <a href="https://colab.research.google.com/github/Nevinjosephantony/ML-/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
path = kagglehub.dataset_download("datamunge/sign-language-mnist")
# Out:
# ...
# 100%|██████████| 62.6M/62.6M [00:00<00:00, 169MB/s]
# Extracting files...

# %%
import os

print(os.listdir(path))
# Out:
# ['amer_sign2.png', 'american_sign_language.PNG', 'sign_mnist_train.csv', 'amer_sign3.png', 'sign_mnist_test.csv', 'sign_mnist_train', 'sign_mnist_test']

# %%
import pandas as pd

df = pd.read_csv(path + "/sign_mnist_train.csv")

print(df.head())
# Out:
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0      3     107     118     127     134     139     143     146     150
# 1      6     155     157     156     156     156     157     156     158
# 2      2     187     188     188     187     187     186     187     188
# 3      2     211     211     212     212     211     210     211     210
# 4     13     164     167     170     172     176     179     180     184
#
#    pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0     153  ...       207       207       207       207       206       206
# 1     158  ...        69       149       128        87        94       163
# 2     187  ...       202       201       200       199       198       199
# 3     210  ...       235       234       233       231       230       226
# 4     185  ...        92       105       105       108       133       163
#
#    pixel781  pixel782  pixel783  pixel784
# ...

# %%
import pandas as pd

train_df = pd.read_csv(path + "/sign_mnist_train.csv")

print(train_df.shape)
print(train_df.head())
# Out:
# (27455, 785)
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0      3     107     118     127     134     139     143     146     150
# 1      6     155     157     156     156     156     157     156     158
# 2      2     187     188     188     187     187     186     187     188
# 3      2     211     211     212     212     211     210     211     210
# 4     13     164     167     170     172     176     179     180     184
#
#    pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0     153  ...       207       207       207       207       206       206
# 1     158  ...        69       149       128        87        94       163
# 2     187  ...       202       201       200       199       198       199
# 3     210  ...       235       234       233       231       230       226
# 4     185  ...        92       105       105       108       133       163
#
#    pixel781  pixel782  pixel783  pixel784
# ...

# %%
print(train_df.columns)
# Out:
# Index(['label', 'pixel1', 'pixel2', 'pixel3', 'pixel4', 'pixel5', 'pixel6',
#        'pixel7', 'pixel8', 'pixel9',
#        ...
#        'pixel775', 'pixel776', 'pixel777', 'pixel778', 'pixel779', 'pixel780',
#        'pixel781', 'pixel782', 'pixel783', 'pixel784'],
#       dtype='object', length=785)

# %%
print(train_df["label"].value_counts())
# Out:
# label
# 17    1294
# 16    1279
# 11    1241
# 22    1225
# 5     1204
# 18    1199
# 14    1196
# 3     1196
# 19    1186
# 23    1164
# 8     1162
# 20    1161
# 13    1151
# 2     1144
# 0     1126
# 24    1118
# 10    1114
# 6     1090
# 15    1088
# 21    1082
# 12    1055
# 7     1013
# 1     1010
# 4      957
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

label = train_df.iloc[0, 0]

image = train_df.iloc[0, 1:].values.reshape(28, 28)

plt.imshow(image, cmap="gray")
plt.title(f"Label: {label}")
plt.axis("off")
plt.show()

# %%
print(train_df["label"].nunique())

print(sorted(train_df["label"].unique()))
# Out:
# 24
# [np.int64(0), np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8), np.int64(10), np.int64(11), np.int64(12), np.int64(13), np.int64(14), np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(19), np.int64(20), np.int64(21), np.int64(22), np.int64(23), np.int64(24)]
